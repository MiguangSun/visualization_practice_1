# %%
pip install pyecharts
# Out:
# Requirement already satisfied: pyecharts in d:\anaconda\lib\site-packages (1.7.1)
# Requirement already satisfied: simplejson in d:\anaconda\lib\site-packages (from pyecharts) (3.17.0)
# Requirement already satisfied: jinja2 in d:\anaconda\lib\site-packages (from pyecharts) (2.11.1)
# Requirement already satisfied: prettytable in d:\anaconda\lib\site-packages (from pyecharts) (0.7.2)
# Requirement already satisfied: MarkupSafe>=0.23 in d:\anaconda\lib\site-packages (from jinja2->pyecharts) (1.1.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import json
import re
import pprint
from pyecharts.charts import Map, Geo
from pyecharts import options as opts

if __name__ == '__main__':
    result = requests.get(
        'https://interface.sina.cn/news/wap/fymap2020_data.d.json?1580097300739&&callback=sinajp_1580097300873005379567841634181')
    json_str = re.search("\(+([^)]*)\)+", result.text).group(1)

    html = f"{json_str}"
    table = json.loads(f"{html}")
    pp = pprint.PrettyPrinter(indent=4)
    data = []
    for province in table['data']['list']:
        pp.pprint(province)
        data.append((province['name'], province['value']))

        for city in province['city']:
            data.append((city['name'], city['conNum']))
            pp.pprint(city)
map_p = Map()
map_p.set_global_opts(title_opts=opts.TitleOpts(title="实时疫情图"), visualmap_opts=opts.VisualMapOpts(max_=100))
map_p.add("确诊", data, maptype="china")
map_p.render("ncov.html")  # 生成html文件
# Out:
# {   'adddaily': {   'conadd': '+10',
#                     'conadd_n': 10,
#                     'cureadd': '+11',
#                     'cureadd_n': 11,
#                     'deathadd': '+0',
#                     'deathadd_n': 0,
#                     'econadd': '-1'},
#     'city': [   {   'citycode': 'CN11010100000000',
#                     'conNum': '14',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1',
#                     'deathNum': '0',
#                     'econNum': '13',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '东城区',
#                     'name': '东城区',
#                     'susNum': '0',
#                     'zerodays': '11'},
#                 {   'citycode': 'CN11010200000000',
#                     'conNum': '53',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '0',
#                     'deathNum': '0',
#                     'econNum': '53',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '西城区',
#                     'name': '西城区',
#                     'susNum': '0',
#                     'zerodays': '27'},
#                 {   'citycode': 'CN11010500000000',
#                     'conNum': '72',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '0',
#                     'deathNum': '0',
#                     'econNum': '72',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '朝阳区',
#                     'name': '朝阳区',
#                     'susNum': '0',
#                     'zerodays': '13'},
#                 {   'citycode': 'CN11010800000000',
#                     'conNum': '63',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '0',
#                     'deathNum': '0',
#                     'econNum': '63',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '海淀区',
#                     'name': '海淀区',
#                     'susNum': '0',
#                     'zerodays': '16'},
#                 {   'citycode': 'CN11010600000000',
#                     'conNum': '43',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3',
#                     'deathNum': '0',
#                     'econNum': '40',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '丰台区',
#                     'name': '丰台区',
#                     'susNum': '0',
#                     'zerodays': '14'},
#                 {   'citycode': 'CN11010700000000',
#                     'conNum': '14',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '9',
#                     'deathNum': '0',
#                     'econNum': '5',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '石景山区',
#                     'name': '石景山区',
#                     'susNum': '0',
#                     'zerodays': '32'},
#                 {   'citycode': 'CN11010900000000',
#                     'conNum': '3',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '2',
#                     'deathNum': '0',
#                     'econNum': '1',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '门头沟区',
#                     'name': '门头沟区',
#                     'susNum': '0',
#                     'zerodays': '43'},
#                 {   'citycode': 'CN11011100000000',
#                     'conNum': '16',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3',
#                     'deathNum': '0',
#                     'econNum': '13',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '房山区',
#                     'name': '房山区',
#                     'susNum': '0',
#                     'zerodays': '29'},
#                 {   'citycode': 'CN11011200000000',
#                     'conNum': '19',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1',
#                     'deathNum': '0',
#                     'econNum': '18',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '通州区',
#                     'name': '通州区',
#                     'susNum': '0',
#                     'zerodays': '27'},
#                 {   'citycode': 'CN11011300000000',
#                     'conNum': '10',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '10',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '顺义区',
#                     'name': '顺义区',
#                     'susNum': '0',
#                     'zerodays': '37'},
#                 {   'citycode': 'CN11011400000000',
#                     'conNum': '29',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '10',
#                     'deathNum': '0',
#                     'econNum': '19',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '昌平区',
#                     'name': '昌平区',
#                     'susNum': '0',
#                     'zerodays': '28'},
#                 {   'citycode': 'CN11011500000000',
#                     'conNum': '39',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '16',
#                     'deathNum': '0',
#                     'econNum': '23',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '大兴区',
#                     'name': '大兴区',
#                     'susNum': '0',
#                     'zerodays': '32'},
#                 {   'citycode': 'CN11011600000000',
#                     'conNum': '7',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '0',
#                     'deathNum': '0',
#                     'econNum': '7',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '怀柔区',
#                     'name': '怀柔区',
#                     'susNum': '0',
#                     'zerodays': '39'},
#                 {   'citycode': 'CN11011800000000',
#                     'conNum': '7',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '0',
#                     'deathNum': '0',
#                     'econNum': '7',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '密云区',
#                     'name': '密云区',
#                     'susNum': '0',
#                     'zerodays': '34'},
#                 {   'citycode': 'CN11011900000000',
#                     'conNum': '1',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '0',
#                     'deathNum': '0',
#                     'econNum': '1',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '延庆区',
#                     'name': '延庆区',
#                     'susNum': '0',
#                     'zerodays': '43'},
#                 {   'citycode': '',
#                     'conNum': '25',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '2',
#                     'deathNum': '0',
#                     'econNum': '23',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '',
#                     'name': '外地来京人员',
#                     'susNum': '0',
#                     'zerodays': '22'},
#                 {   'citycode': '',
#                     'conNum': '41',
#                     'conadd': '10',
#                     'conadd_str': '+10',
#                     'cureNum': '3',
#                     'deathNum': '0',
#                     'econNum': '38',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '',
#                     'name': '境外输入人员',
#                     'susNum': '0',
#                     'zerodays': '0'}],
#     'conadd': '10',
#     'cureNum': '369',
#     'deathNum': '8',
#     'econNum': '79',
#     'ename': 'beijing',
#     'hejian': '',
#     'jwsr': '含境外输入',
#     'name': '北京',
#     'susNum': '36',
#     'value': '456',
#     'zerodays': '0'}
# {   'citycode': 'CN11010100000000',
#     'conNum': '14',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'econNum': '13',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '东城区',
#     'name': '东城区',
#     'susNum': '0',
#     'zerodays': '11'}
# {   'citycode': 'CN11010200000000',
#     'conNum': '53',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'econNum': '53',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '西城区',
#     'name': '西城区',
#     'susNum': '0',
#     'zerodays': '27'}
# {   'citycode': 'CN11010500000000',
#     'conNum': '72',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'econNum': '72',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '朝阳区',
#     'name': '朝阳区',
#     'susNum': '0',
#     'zerodays': '13'}
# {   'citycode': 'CN11010800000000',
#     'conNum': '63',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'econNum': '63',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '海淀区',
#     'name': '海淀区',
#     'susNum': '0',
#     'zerodays': '16'}
# {   'citycode': 'CN11010600000000',
#     'conNum': '43',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'econNum': '40',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '丰台区',
#     'name': '丰台区',
#     'susNum': '0',
#     'zerodays': '14'}
# {   'citycode': 'CN11010700000000',
#     'conNum': '14',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '9',
#     'deathNum': '0',
#     'econNum': '5',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '石景山区',
#     'name': '石景山区',
#     'susNum': '0',
#     'zerodays': '32'}
# {   'citycode': 'CN11010900000000',
#     'conNum': '3',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'econNum': '1',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '门头沟区',
#     'name': '门头沟区',
#     'susNum': '0',
#     'zerodays': '43'}
# {   'citycode': 'CN11011100000000',
#     'conNum': '16',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'econNum': '13',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '房山区',
#     'name': '房山区',
#     'susNum': '0',
#     'zerodays': '29'}
# {   'citycode': 'CN11011200000000',
#     'conNum': '19',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'econNum': '18',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '通州区',
#     'name': '通州区',
#     'susNum': '0',
#     'zerodays': '27'}
# {   'citycode': 'CN11011300000000',
#     'conNum': '10',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '顺义区',
#     'name': '顺义区',
#     'susNum': '0',
#     'zerodays': '37'}
# {   'citycode': 'CN11011400000000',
#     'conNum': '29',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '10',
#     'deathNum': '0',
#     'econNum': '19',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '昌平区',
#     'name': '昌平区',
#     'susNum': '0',
#     'zerodays': '28'}
# {   'citycode': 'CN11011500000000',
#     'conNum': '39',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '16',
#     'deathNum': '0',
#     'econNum': '23',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '大兴区',
#     'name': '大兴区',
#     'susNum': '0',
#     'zerodays': '32'}
# {   'citycode': 'CN11011600000000',
#     'conNum': '7',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'econNum': '7',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '怀柔区',
#     'name': '怀柔区',
#     'susNum': '0',
#     'zerodays': '39'}
# {   'citycode': 'CN11011800000000',
#     'conNum': '7',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'econNum': '7',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '密云区',
#     'name': '密云区',
#     'susNum': '0',
#     'zerodays': '34'}
# {   'citycode': 'CN11011900000000',
#     'conNum': '1',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '0',
#     'deathNum': '0',
#     'econNum': '1',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '延庆区',
#     'name': '延庆区',
#     'susNum': '0',
#     'zerodays': '43'}
# {   'citycode': '',
#     'conNum': '25',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'econNum': '23',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '',
#     'name': '外地来京人员',
#     'susNum': '0',
#     'zerodays': '22'}
# {   'citycode': '',
#     'conNum': '41',
#     'conadd': '10',
#     'conadd_str': '+10',
#     'cureNum': '3',
#     'deathNum': '0',
#     'econNum': '38',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '',
#     'name': '境外输入人员',
#     'susNum': '0',
#     'zerodays': '0'}
# {   'adddaily': {   'conadd': '+1',
#                     'conadd_n': 1,
#                     'cureadd': '+894',
#                     'cureadd_n': 894,
#                     'deathadd': '+12',
#                     'deathadd_n': 12,
#                     'econadd': '-905'},
#     'city': [   {   'citycode': 'CN42010000000000',
#                     'conNum': '50004',
#                     'conadd': '1',
#                     'conadd_str': '+1',
#                     'cureNum': '39220',
#                     'deathNum': '2480',
#                     'econNum': '8304',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '武汉市',
#                     'name': '武汉',
#                     'susNum': '0',
#                     'zerodays': '-1'},
#                 {   'citycode': 'CN42110000000000',
#                     'conNum': '2907',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '2756',
#                     'deathNum': '125',
#                     'econNum': '26',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '黄冈市',
#                     'name': '黄冈',
#                     'susNum': '0',
#                     'zerodays': '14'},
#                 {   'citycode': 'CN42090000000000',
#                     'conNum': '3518',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3278',
#                     'deathNum': '127',
#                     'econNum': '113',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '孝感市',
#                     'name': '孝感',
#                     'susNum': '0',
#                     'zerodays': '17'},
#                 {   'citycode': 'CN42080000000000',
#                     'conNum': '928',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '868',
#                     'deathNum': '39',
#                     'econNum': '21',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '荆门市',
#                     'name': '荆门',
#                     'susNum': '0',
#                     'zerodays': '14'},
#                 {   'citycode': 'CN42120000000000',
#                     'conNum': '836',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '821',
#                     'deathNum': '15',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '咸宁市',
#                     'name': '咸宁',
#                     'susNum': '0',
#                     'zerodays': '24'},
#                 {   'citycode': 'CN42100000000000',
#                     'conNum': '1580',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1498',
#                     'deathNum': '50',
#                     'econNum': '32',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '荆州市',
#                     'name': '荆州',
#                     'susNum': '0',
#                     'zerodays': '15'},
#                 {   'citycode': 'CN42060000000000',
#                     'conNum': '1175',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1129',
#                     'deathNum': '38',
#                     'econNum': '8',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '襄阳市',
#                     'name': '襄阳',
#                     'susNum': '0',
#                     'zerodays': '21'},
#                 {   'citycode': 'CN42130000000000',
#                     'conNum': '1307',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1221',
#                     'deathNum': '45',
#                     'econNum': '41',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '随州市',
#                     'name': '随州',
#                     'susNum': '0',
#                     'zerodays': '19'},
#                 {   'citycode': 'CN42030000000000',
#                     'conNum': '672',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '638',
#                     'deathNum': '8',
#                     'econNum': '26',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '十堰市',
#                     'name': '十堰',
#                     'susNum': '0',
#                     'zerodays': '16'},
#                 {   'citycode': 'CN42070000000000',
#                     'conNum': '1394',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1280',
#                     'deathNum': '57',
#                     'econNum': '57',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '鄂州市',
#                     'name': '鄂州',
#                     'susNum': '0',
#                     'zerodays': '12'},
#                 {   'citycode': 'CN42020000000000',
#                     'conNum': '1015',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '960',
#                     'deathNum': '38',
#                     'econNum': '17',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '黄石市',
#                     'name': '黄石',
#                     'susNum': '0',
#                     'zerodays': '12'},
#                 {   'citycode': 'CN42050000000000',
#                     'conNum': '931',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '873',
#                     'deathNum': '36',
#                     'econNum': '22',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '宜昌市',
#                     'name': '宜昌',
#                     'susNum': '0',
#                     'zerodays': '18'},
#                 {   'citycode': 'CN42280000000000',
#                     'conNum': '252',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '243',
#                     'deathNum': '7',
#                     'econNum': '2',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '恩施土家族苗族自治州',
#                     'name': '恩施州',
#                     'susNum': '0',
#                     'zerodays': '17'},
#                 {   'citycode': 'CN42900400000000',
#                     'conNum': '575',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '531',
#                     'deathNum': '22',
#                     'econNum': '22',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '仙桃市',
#                     'name': '仙桃',
#                     'susNum': '0',
#                     'zerodays': '21'},
#                 {   'citycode': 'CN42900600000000',
#                     'conNum': '496',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '477',
#                     'deathNum': '15',
#                     'econNum': '4',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '天门市',
#                     'name': '天门',
#                     'susNum': '0',
#                     'zerodays': '20'},
#                 {   'citycode': 'CN42900500000000',
#                     'conNum': '198',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '184',
#                     'deathNum': '9',
#                     'econNum': '5',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '潜江市',
#                     'name': '潜江',
#                     'susNum': '0',
#                     'zerodays': '18'},
#                 {   'citycode': 'CN42902100000000',
#                     'conNum': '11',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '11',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '神农架林区',
#                     'name': '神农架林区',
#                     'susNum': '0',
#                     'zerodays': '24'}],
#     'conadd': '1',
#     'cureNum': '55988',
#     'deathNum': '3111',
#     'econNum': '8700',
#     'ename': 'hubei',
#     'hejian': '',
#     'jwsr': '',
#     'name': '湖北',
#     'susNum': '0',
#     'value': '67799',
#     'zerodays': '-1'}
# {   'citycode': 'CN42010000000000',
#     'conNum': '50004',
#     'conadd': '1',
#     'conadd_str': '+1',
#     'cureNum': '39220',
#     'deathNum': '2480',
#     'econNum': '8304',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '武汉市',
#     'name': '武汉',
#     'susNum': '0',
#     'zerodays': '-1'}
# {   'citycode': 'CN42110000000000',
#     'conNum': '2907',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '2756',
#     'deathNum': '125',
#     'econNum': '26',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '黄冈市',
#     'name': '黄冈',
#     'susNum': '0',
#     'zerodays': '14'}
# {   'citycode': 'CN42090000000000',
#     'conNum': '3518',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3278',
#     'deathNum': '127',
#     'econNum': '113',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '孝感市',
#     'name': '孝感',
#     'susNum': '0',
#     'zerodays': '17'}
# {   'citycode': 'CN42080000000000',
#     'conNum': '928',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '868',
#     'deathNum': '39',
#     'econNum': '21',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '荆门市',
#     'name': '荆门',
#     'susNum': '0',
#     'zerodays': '14'}
# {   'citycode': 'CN42120000000000',
#     'conNum': '836',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '821',
#     'deathNum': '15',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '咸宁市',
#     'name': '咸宁',
#     'susNum': '0',
#     'zerodays': '24'}
# {   'citycode': 'CN42100000000000',
#     'conNum': '1580',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1498',
#     'deathNum': '50',
#     'econNum': '32',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '荆州市',
#     'name': '荆州',
#     'susNum': '0',
#     'zerodays': '15'}
# {   'citycode': 'CN42060000000000',
#     'conNum': '1175',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1129',
#     'deathNum': '38',
#     'econNum': '8',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '襄阳市',
#     'name': '襄阳',
#     'susNum': '0',
#     'zerodays': '21'}
# {   'citycode': 'CN42130000000000',
#     'conNum': '1307',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1221',
#     'deathNum': '45',
#     'econNum': '41',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '随州市',
#     'name': '随州',
#     'susNum': '0',
#     'zerodays': '19'}
# {   'citycode': 'CN42030000000000',
#     'conNum': '672',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '638',
#     'deathNum': '8',
#     'econNum': '26',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '十堰市',
#     'name': '十堰',
#     'susNum': '0',
#     'zerodays': '16'}
# {   'citycode': 'CN42070000000000',
#     'conNum': '1394',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1280',
#     'deathNum': '57',
#     'econNum': '57',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '鄂州市',
#     'name': '鄂州',
#     'susNum': '0',
#     'zerodays': '12'}
# {   'citycode': 'CN42020000000000',
#     'conNum': '1015',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '960',
#     'deathNum': '38',
#     'econNum': '17',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '黄石市',
#     'name': '黄石',
#     'susNum': '0',
#     'zerodays': '12'}
# {   'citycode': 'CN42050000000000',
#     'conNum': '931',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '873',
#     'deathNum': '36',
#     'econNum': '22',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '宜昌市',
#     'name': '宜昌',
#     'susNum': '0',
#     'zerodays': '18'}
# {   'citycode': 'CN42280000000000',
#     'conNum': '252',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '243',
#     'deathNum': '7',
#     'econNum': '2',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '恩施土家族苗族自治州',
#     'name': '恩施州',
#     'susNum': '0',
#     'zerodays': '17'}
# {   'citycode': 'CN42900400000000',
#     'conNum': '575',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '531',
#     'deathNum': '22',
#     'econNum': '22',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '仙桃市',
#     'name': '仙桃',
#     'susNum': '0',
#     'zerodays': '21'}
# {   'citycode': 'CN42900600000000',
#     'conNum': '496',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '477',
#     'deathNum': '15',
#     'econNum': '4',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '天门市',
#     'name': '天门',
#     'susNum': '0',
#     'zerodays': '20'}
# {   'citycode': 'CN42900500000000',
#     'conNum': '198',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '184',
#     'deathNum': '9',
#     'econNum': '5',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '潜江市',
#     'name': '潜江',
#     'susNum': '0',
#     'zerodays': '18'}
# {   'citycode': 'CN42902100000000',
#     'conNum': '11',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '11',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '神农架林区',
#     'name': '神农架林区',
#     'susNum': '0',
#     'zerodays': '24'}
# {   'adddaily': {   'conadd': '+3',
#                     'conadd_n': 3,
#                     'cureadd': '+1',
#                     'cureadd_n': 1,
#                     'deathadd': '+0',
#                     'deathadd_n': 0,
#                     'econadd': '+2'},
#     'city': [   {   'citycode': 'CN44030000000000',
#                     'conNum': '423',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '402',
#                     'deathNum': '3',
#                     'econNum': '18',
#                     'hejian': '',
#                     'jwsr': '含境外输入',
#                     'mapName': '深圳市',
#                     'name': '深圳',
#                     'susNum': '0',
#                     'zerodays': '2'},
#                 {   'citycode': 'CN44010000000000',
#                     'conNum': '351',
#                     'conadd': '3',
#                     'conadd_str': '+3',
#                     'cureNum': '330',
#                     'deathNum': '1',
#                     'econNum': '20',
#                     'hejian': '',
#                     'jwsr': '含境外输入',
#                     'mapName': '广州市',
#                     'name': '广州',
#                     'susNum': '0',
#                     'zerodays': '0'},
#                 {   'citycode': 'CN44190000000000',
#                     'conNum': '100',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '97',
#                     'deathNum': '1',
#                     'econNum': '2',
#                     'hejian': '',
#                     'jwsr': '含境外输入',
#                     'mapName': '东莞市',
#                     'name': '东莞',
#                     'susNum': '0',
#                     'zerodays': '8'},
#                 {   'citycode': 'CN44040000000000',
#                     'conNum': '98',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '97',
#                     'deathNum': '1',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '珠海市',
#                     'name': '珠海',
#                     'susNum': '0',
#                     'zerodays': '29'},
#                 {   'citycode': 'CN44060000000000',
#                     'conNum': '85',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '81',
#                     'deathNum': '0',
#                     'econNum': '4',
#                     'hejian': '',
#                     'jwsr': '含境外输入',
#                     'mapName': '佛山市',
#                     'name': '佛山',
#                     'susNum': '0',
#                     'zerodays': '2'},
#                 {   'citycode': 'CN44200000000000',
#                     'conNum': '68',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '64',
#                     'deathNum': '0',
#                     'econNum': '4',
#                     'hejian': '',
#                     'jwsr': '含境外输入',
#                     'mapName': '中山市',
#                     'name': '中山',
#                     'susNum': '0',
#                     'zerodays': '6'},
#                 {   'citycode': 'CN44130000000000',
#                     'conNum': '62',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '62',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '惠州市',
#                     'name': '惠州',
#                     'susNum': '0',
#                     'zerodays': '28'},
#                 {   'citycode': 'CN44050000000000',
#                     'conNum': '25',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '24',
#                     'deathNum': '0',
#                     'econNum': '1',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '汕头市',
#                     'name': '汕头',
#                     'susNum': '0',
#                     'zerodays': '39'},
#                 {   'citycode': 'CN44070000000000',
#                     'conNum': '23',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '23',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '江门市',
#                     'name': '江门',
#                     'susNum': '0',
#                     'zerodays': '31'},
#                 {   'citycode': 'CN44080000000000',
#                     'conNum': '22',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '22',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '湛江市',
#                     'name': '湛江',
#                     'susNum': '0',
#                     'zerodays': '33'},
#                 {   'citycode': 'CN44120000000000',
#                     'conNum': '19',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '18',
#                     'deathNum': '1',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '肇庆市',
#                     'name': '肇庆',
#                     'susNum': '0',
#                     'zerodays': '25'},
#                 {   'citycode': 'CN44140000000000',
#                     'conNum': '16',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '16',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '梅州市',
#                     'name': '梅州',
#                     'susNum': '0',
#                     'zerodays': '31'},
#                 {   'citycode': 'CN44090000000000',
#                     'conNum': '14',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '14',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '茂名市',
#                     'name': '茂名',
#                     'susNum': '0',
#                     'zerodays': '30'},
#                 {   'citycode': 'CN44170000000000',
#                     'conNum': '14',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '14',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '阳江市',
#                     'name': '阳江',
#                     'susNum': '0',
#                     'zerodays': '23'},
#                 {   'citycode': 'CN44180000000000',
#                     'conNum': '12',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '12',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '清远市',
#                     'name': '清远',
#                     'susNum': '0',
#                     'zerodays': '35'},
#                 {   'citycode': 'CN44020000000000',
#                     'conNum': '10',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '9',
#                     'deathNum': '1',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '韶关市',
#                     'name': '韶关',
#                     'susNum': '0',
#                     'zerodays': '32'},
#                 {   'citycode': 'CN44520000000000',
#                     'conNum': '8',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '8',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '揭阳市',
#                     'name': '揭阳',
#                     'susNum': '0',
#                     'zerodays': '36'},
#                 {   'citycode': 'CN44150000000000',
#                     'conNum': '5',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '5',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '汕尾市',
#                     'name': '汕尾',
#                     'susNum': '0',
#                     'zerodays': '44'},
#                 {   'citycode': 'CN44510000000000',
#                     'conNum': '5',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '5',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '潮州市',
#                     'name': '潮州',
#                     'susNum': '0',
#                     'zerodays': '41'},
#                 {   'citycode': 'CN44160000000000',
#                     'conNum': '4',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '4',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '河源市',
#                     'name': '河源',
#                     'susNum': '0',
#                     'zerodays': '30'}],
#     'conadd': '3',
#     'cureNum': '1307',
#     'deathNum': '8',
#     'econNum': '49',
#     'ename': 'guangdong',
#     'hejian': '',
#     'jwsr': '含境外输入',
#     'name': '广东',
#     'susNum': '0',
#     'value': '1364',
#     'zerodays': '0'}
# {   'citycode': 'CN44030000000000',
#     'conNum': '423',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '402',
#     'deathNum': '3',
#     'econNum': '18',
#     'hejian': '',
#     'jwsr': '含境外输入',
#     'mapName': '深圳市',
#     'name': '深圳',
#     'susNum': '0',
#     'zerodays': '2'}
# {   'citycode': 'CN44010000000000',
#     'conNum': '351',
#     'conadd': '3',
#     'conadd_str': '+3',
#     'cureNum': '330',
#     'deathNum': '1',
#     'econNum': '20',
#     'hejian': '',
#     'jwsr': '含境外输入',
#     'mapName': '广州市',
#     'name': '广州',
#     'susNum': '0',
#     'zerodays': '0'}
# {   'citycode': 'CN44190000000000',
#     'conNum': '100',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '97',
#     'deathNum': '1',
#     'econNum': '2',
#     'hejian': '',
#     'jwsr': '含境外输入',
#     'mapName': '东莞市',
#     'name': '东莞',
#     'susNum': '0',
#     'zerodays': '8'}
# {   'citycode': 'CN44040000000000',
#     'conNum': '98',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '97',
#     'deathNum': '1',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '珠海市',
#     'name': '珠海',
#     'susNum': '0',
#     'zerodays': '29'}
# {   'citycode': 'CN44060000000000',
#     'conNum': '85',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '81',
#     'deathNum': '0',
#     'econNum': '4',
#     'hejian': '',
#     'jwsr': '含境外输入',
#     'mapName': '佛山市',
#     'name': '佛山',
#     'susNum': '0',
#     'zerodays': '2'}
# {   'citycode': 'CN44200000000000',
#     'conNum': '68',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '64',
#     'deathNum': '0',
#     'econNum': '4',
#     'hejian': '',
#     'jwsr': '含境外输入',
#     'mapName': '中山市',
#     'name': '中山',
#     'susNum': '0',
#     'zerodays': '6'}
# {   'citycode': 'CN44130000000000',
#     'conNum': '62',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '62',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '惠州市',
#     'name': '惠州',
#     'susNum': '0',
#     'zerodays': '28'}
# {   'citycode': 'CN44050000000000',
#     'conNum': '25',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '24',
#     'deathNum': '0',
#     'econNum': '1',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '汕头市',
#     'name': '汕头',
#     'susNum': '0',
#     'zerodays': '39'}
# {   'citycode': 'CN44070000000000',
#     'conNum': '23',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '23',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '江门市',
#     'name': '江门',
#     'susNum': '0',
#     'zerodays': '31'}
# {   'citycode': 'CN44080000000000',
#     'conNum': '22',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '22',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '湛江市',
#     'name': '湛江',
#     'susNum': '0',
#     'zerodays': '33'}
# {   'citycode': 'CN44120000000000',
#     'conNum': '19',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '18',
#     'deathNum': '1',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '肇庆市',
#     'name': '肇庆',
#     'susNum': '0',
#     'zerodays': '25'}
# {   'citycode': 'CN44140000000000',
#     'conNum': '16',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '16',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '梅州市',
#     'name': '梅州',
#     'susNum': '0',
#     'zerodays': '31'}
# {   'citycode': 'CN44090000000000',
#     'conNum': '14',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '14',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '茂名市',
#     'name': '茂名',
#     'susNum': '0',
#     'zerodays': '30'}
# {   'citycode': 'CN44170000000000',
#     'conNum': '14',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '14',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '阳江市',
#     'name': '阳江',
#     'susNum': '0',
#     'zerodays': '23'}
# {   'citycode': 'CN44180000000000',
#     'conNum': '12',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '12',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '清远市',
#     'name': '清远',
#     'susNum': '0',
#     'zerodays': '35'}
# {   'citycode': 'CN44020000000000',
#     'conNum': '10',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '9',
#     'deathNum': '1',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '韶关市',
#     'name': '韶关',
#     'susNum': '0',
#     'zerodays': '32'}
# {   'citycode': 'CN44520000000000',
#     'conNum': '8',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '8',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '揭阳市',
#     'name': '揭阳',
#     'susNum': '0',
#     'zerodays': '36'}
# {   'citycode': 'CN44150000000000',
#     'conNum': '5',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '汕尾市',
#     'name': '汕尾',
#     'susNum': '0',
#     'zerodays': '44'}
# {   'citycode': 'CN44510000000000',
#     'conNum': '5',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '潮州市',
#     'name': '潮州',
#     'susNum': '0',
#     'zerodays': '41'}
# {   'citycode': 'CN44160000000000',
#     'conNum': '4',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '河源市',
#     'name': '河源',
#     'susNum': '0',
#     'zerodays': '30'}
# {   'adddaily': {   'conadd': '+1',
#                     'conadd_n': 1,
#                     'cureadd': '+3',
#                     'cureadd_n': 3,
#                     'deathadd': '+0',
#                     'deathadd_n': 0,
#                     'econadd': '-2'},
#     'city': [   {   'citycode': 'CN33010000000000',
#                     'conNum': '183',
#                     'conadd': '1',
#                     'conadd_str': '+1',
#                     'cureNum': '181',
#                     'deathNum': '0',
#                     'econNum': '2',
#                     'hejian': '',
#                     'jwsr': '含境外输入',
#                     'mapName': '杭州市',
#                     'name': '杭州',
#                     'susNum': '0',
#                     'zerodays': '0'},
#                 {   'citycode': 'CN33020000000000',
#                     'conNum': '157',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '157',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '宁波市',
#                     'name': '宁波',
#                     'susNum': '0',
#                     'zerodays': '26'},
#                 {   'citycode': 'CN33030000000000',
#                     'conNum': '504',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '503',
#                     'deathNum': '1',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '温州市',
#                     'name': '温州',
#                     'susNum': '0',
#                     'zerodays': '29'},
#                 {   'citycode': 'CN33050000000000',
#                     'conNum': '12',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '10',
#                     'deathNum': '0',
#                     'econNum': '2',
#                     'hejian': '',
#                     'jwsr': '含境外输入',
#                     'mapName': '湖州市',
#                     'name': '湖州',
#                     'susNum': '0',
#                     'zerodays': '13'},
#                 {   'citycode': 'CN33040000000000',
#                     'conNum': '45',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '44',
#                     'deathNum': '0',
#                     'econNum': '1',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '嘉兴市',
#                     'name': '嘉兴',
#                     'susNum': '0',
#                     'zerodays': '27'},
#                 {   'citycode': 'CN33060000000000',
#                     'conNum': '42',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '42',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '绍兴市',
#                     'name': '绍兴',
#                     'susNum': '0',
#                     'zerodays': '33'},
#                 {   'citycode': 'CN33070000000000',
#                     'conNum': '55',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '55',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '金华市',
#                     'name': '金华',
#                     'susNum': '0',
#                     'zerodays': '34'},
#                 {   'citycode': 'CN33080000000000',
#                     'conNum': '14',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '14',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '衢州市',
#                     'name': '衢州',
#                     'susNum': '0',
#                     'zerodays': '26'},
#                 {   'citycode': 'CN33090000000000',
#                     'conNum': '10',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '10',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '舟山市',
#                     'name': '舟山',
#                     'susNum': '0',
#                     'zerodays': '36'},
#                 {   'citycode': 'CN33100000000000',
#                     'conNum': '146',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '146',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '台州市',
#                     'name': '台州',
#                     'susNum': '0',
#                     'zerodays': '31'},
#                 {   'citycode': 'CN33110000000000',
#                     'conNum': '28',
#                     'conadd': '0',
# ...
#                     'mapName': '西宁市',
#                     'name': '西宁',
#                     'susNum': '0',
#                     'zerodays': '41'},
#                 {   'citycode': 'CN63220000000000',
#                     'conNum': '3',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '海北藏族自治州',
#                     'name': '海北州',
#                     'susNum': '0',
#                     'zerodays': '43'}],
#     'conadd': '0',
#     'cureNum': '18',
#     'deathNum': '0',
#     'econNum': '0',
#     'ename': 'qinghai',
#     'hejian': '',
#     'jwsr': '',
#     'name': '青海',
#     'susNum': '0',
#     'value': '18',
#     'zerodays': '41'}
# {   'citycode': 'CN63010000000000',
#     'conNum': '15',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '15',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '西宁市',
#     'name': '西宁',
#     'susNum': '0',
#     'zerodays': '41'}
# {   'citycode': 'CN63220000000000',
#     'conNum': '3',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '海北藏族自治州',
#     'name': '海北州',
#     'susNum': '0',
#     'zerodays': '43'}
# {   'adddaily': {   'conadd': '+0',
#                     'conadd_n': 0,
#                     'cureadd': '+0',
#                     'cureadd_n': 0,
#                     'deathadd': '+0',
#                     'deathadd_n': 0,
#                     'econadd': '+0'},
#     'city': [   {   'citycode': 'CN65010000000000',
#                     'conNum': '23',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '23',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '乌鲁木齐市',
#                     'name': '乌鲁木齐',
#                     'susNum': '0',
#                     'zerodays': '33'},
#                 {   'citycode': 'CN65400000000000',
#                     'conNum': '18',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '18',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '伊犁哈萨克自治州',
#                     'name': '伊犁州',
#                     'susNum': '0',
#                     'zerodays': '30'},
#                 {   'citycode': 'CN65230000000000',
#                     'conNum': '4',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '4',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '昌吉回族自治州',
#                     'name': '昌吉州',
#                     'susNum': '0',
#                     'zerodays': '36'},
#                 {   'citycode': 'CN65040000000000',
#                     'conNum': '3',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '吐鲁番市',
#                     'name': '吐鲁番',
#                     'susNum': '0',
#                     'zerodays': '31'},
#                 {   'citycode': 'CN65280000000000',
#                     'conNum': '3',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '巴音郭楞蒙古自治州',
#                     'name': '巴州',
#                     'susNum': '0',
#                     'zerodays': '38'},
#                 {   'citycode': 'CN65290000000000',
#                     'conNum': '1',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '阿克苏地区',
#                     'name': '阿克苏地区',
#                     'susNum': '0',
#                     'zerodays': '47'},
#                 {   'citycode': 'CN65900400000000',
#                     'conNum': '2',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '2',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '五家渠市',
#                     'name': '五家渠',
#                     'susNum': '0',
#                     'zerodays': '32'},
#                 {   'citycode': 'CN65900100000000',
#                     'conNum': '4',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3',
#                     'deathNum': '1',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '石河子市',
#                     'name': '石河子',
#                     'susNum': '0',
#                     'zerodays': '29'},
#                 {   'citycode': '',
#                     'conNum': '10',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '9',
#                     'deathNum': '1',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '',
#                     'name': '第四师',
#                     'susNum': '0',
#                     'zerodays': '21'},
#                 {   'citycode': '',
#                     'conNum': '1',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '新疆生产建设兵团第七师',
#                     'name': '第七师',
#                     'susNum': '0',
#                     'zerodays': '21'},
#                 {   'citycode': '',
#                     'conNum': '4',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3',
#                     'deathNum': '1',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '新疆生产建设兵团第九师',
#                     'name': '第九师',
#                     'susNum': '0',
#                     'zerodays': '21'},
#                 {   'citycode': '',
#                     'conNum': '3',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '3',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '',
#                     'name': '第十二师',
#                     'susNum': '0',
#                     'zerodays': '21'}],
#     'conadd': '0',
#     'cureNum': '73',
#     'deathNum': '3',
#     'econNum': '0',
#     'ename': 'xinjiang',
#     'hejian': '',
#     'jwsr': '',
#     'name': '新疆',
#     'susNum': '0',
#     'value': '76',
#     'zerodays': '21'}
# {   'citycode': 'CN65010000000000',
#     'conNum': '23',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '23',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '乌鲁木齐市',
#     'name': '乌鲁木齐',
#     'susNum': '0',
#     'zerodays': '33'}
# {   'citycode': 'CN65400000000000',
#     'conNum': '18',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '18',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '伊犁哈萨克自治州',
#     'name': '伊犁州',
#     'susNum': '0',
#     'zerodays': '30'}
# {   'citycode': 'CN65230000000000',
#     'conNum': '4',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '昌吉回族自治州',
#     'name': '昌吉州',
#     'susNum': '0',
#     'zerodays': '36'}
# {   'citycode': 'CN65040000000000',
#     'conNum': '3',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '吐鲁番市',
#     'name': '吐鲁番',
#     'susNum': '0',
#     'zerodays': '31'}
# {   'citycode': 'CN65280000000000',
#     'conNum': '3',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '巴音郭楞蒙古自治州',
#     'name': '巴州',
#     'susNum': '0',
#     'zerodays': '38'}
# {   'citycode': 'CN65290000000000',
#     'conNum': '1',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '阿克苏地区',
#     'name': '阿克苏地区',
#     'susNum': '0',
#     'zerodays': '47'}
# {   'citycode': 'CN65900400000000',
#     'conNum': '2',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '2',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '五家渠市',
#     'name': '五家渠',
#     'susNum': '0',
#     'zerodays': '32'}
# {   'citycode': 'CN65900100000000',
#     'conNum': '4',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3',
#     'deathNum': '1',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '石河子市',
#     'name': '石河子',
#     'susNum': '0',
#     'zerodays': '29'}
# {   'citycode': '',
#     'conNum': '10',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '9',
#     'deathNum': '1',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '',
#     'name': '第四师',
#     'susNum': '0',
#     'zerodays': '21'}
# {   'citycode': '',
#     'conNum': '1',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '新疆生产建设兵团第七师',
#     'name': '第七师',
#     'susNum': '0',
#     'zerodays': '21'}
# {   'citycode': '',
#     'conNum': '4',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3',
#     'deathNum': '1',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '新疆生产建设兵团第九师',
#     'name': '第九师',
#     'susNum': '0',
#     'zerodays': '21'}
# {   'citycode': '',
#     'conNum': '3',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '3',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '',
#     'name': '第十二师',
#     'susNum': '0',
#     'zerodays': '21'}
# {   'adddaily': {   'conadd': '+0',
#                     'conadd_n': 0,
#                     'cureadd': '+2',
#                     'cureadd_n': 2,
#                     'deathadd': '+0',
#                     'deathadd_n': 0,
#                     'econadd': '-2'},
#     'city': [   {   'citycode': 'CN64010000000000',
#                     'conNum': '36',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '36',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '银川市',
#                     'name': '银川',
#                     'susNum': '0',
#                     'zerodays': '14'},
#                 {   'citycode': 'CN64020000000000',
#                     'conNum': '1',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '石嘴山市',
#                     'name': '石嘴山',
#                     'susNum': '0',
#                     'zerodays': '43'},
#                 {   'citycode': 'CN64030000000000',
#                     'conNum': '28',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '28',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '吴忠市',
#                     'name': '吴忠',
#                     'susNum': '0',
#                     'zerodays': '28'},
#                 {   'citycode': 'CN64040000000000',
#                     'conNum': '5',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '5',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '固原市',
#                     'name': '固原',
#                     'susNum': '0',
#                     'zerodays': '34'},
#                 {   'citycode': 'CN64050000000000',
#                     'conNum': '4',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '4',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '中卫市',
#                     'name': '中卫',
#                     'susNum': '0',
#                     'zerodays': '20'},
#                 {   'citycode': '',
#                     'conNum': '1',
#                     'conadd': '0',
#                     'conadd_str': '+0',
#                     'cureNum': '1',
#                     'deathNum': '0',
#                     'econNum': '0',
#                     'hejian': '',
#                     'jwsr': '',
#                     'mapName': '',
#                     'name': '宁东',
#                     'susNum': '0',
#                     'zerodays': '21'}],
#     'conadd': '0',
#     'cureNum': '75',
#     'deathNum': '0',
#     'econNum': '0',
#     'ename': 'ningxia',
#     'hejian': '',
#     'jwsr': '含境外输入',
#     'name': '宁夏',
#     'susNum': '0',
#     'value': '75',
#     'zerodays': '14'}
# {   'citycode': 'CN64010000000000',
#     'conNum': '36',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '36',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '银川市',
#     'name': '银川',
#     'susNum': '0',
#     'zerodays': '14'}
# {   'citycode': 'CN64020000000000',
#     'conNum': '1',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '石嘴山市',
#     'name': '石嘴山',
#     'susNum': '0',
#     'zerodays': '43'}
# {   'citycode': 'CN64030000000000',
#     'conNum': '28',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '28',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '吴忠市',
#     'name': '吴忠',
#     'susNum': '0',
#     'zerodays': '28'}
# {   'citycode': 'CN64040000000000',
#     'conNum': '5',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '5',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '固原市',
#     'name': '固原',
#     'susNum': '0',
#     'zerodays': '34'}
# {   'citycode': 'CN64050000000000',
#     'conNum': '4',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '4',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '中卫市',
#     'name': '中卫',
#     'susNum': '0',
#     'zerodays': '20'}
# {   'citycode': '',
#     'conNum': '1',
#     'conadd': '0',
#     'conadd_str': '+0',
#     'cureNum': '1',
#     'deathNum': '0',
#     'econNum': '0',
#     'hejian': '',
#     'jwsr': '',
#     'mapName': '',
#     'name': '宁东',
#     'susNum': '0',
#     'zerodays': '21'}
# 'C:\\Users\\sunmi\\ncov.html'
